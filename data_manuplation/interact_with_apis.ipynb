# %%
import requests as http
import pandas as pd

url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
# return json
res = http.get(url, timeout=10, verify=False)
jsonData = res.json()

df = pd.DataFrame(jsonData,columns=['number'])
df.head()
# Out:
# c:\Users\ahmed\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#    number
# 0   65274
# 1   65273
# 2   65272
# 3   65270
# 4   65268

# %%
first_item = pd.DataFrame([jsonData[0]])

first_item.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           html_url          id  \
# 0  https://github.com/pandas-dev/pandas/pull/65274  4286243773
#
#                node_id  number  \
# 0  PR_kwDOAA0YD87TfyLi   65274
#
#                                                title  ...  type  \
# 0  ref:Avoid state mutation in FrameApply.agg by ...  ...  None
#
#   active_lock_reason draft                                       pull_request  \
# ...
