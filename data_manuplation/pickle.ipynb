# %%
import pandas as pd

df = pd.read_csv(r'D:\actors.csv')

# save DataFrame to disk as pickle
df.to_pickle('actors.pkl')

# load it back later — exactly as it was
df2 = pd.read_pickle('actors.pkl')
print(df2)
# Out:
#                   Name       Nationality  Birth Year  \
# 0            Tom Hanks          American        1956
# 1    Leonardo DiCaprio          American        1974
# 2         Meryl Streep          American        1949
# 3       Cate Blanchett        Australian        1969
# 4    Denzel Washington          American        1954
# 5      Natalie Portman  Israeli-American        1981
# 6            Brad Pitt          American        1963
# 7          Viola Davis          American        1965
# 8       Morgan Freeman          American        1937
# 9   Scarlett Johansson          American        1984
# 10     Anthony Hopkins             Welsh        1937
# 11     Charlize Theron     South African        1975
#
#                    Known For           Genre  Active Since    Awards
# 0               Forrest Gump    Drama/Comedy          1980  2 Oscars
# 1               The Revenant  Drama/Thriller          1991   1 Oscar
# ...
